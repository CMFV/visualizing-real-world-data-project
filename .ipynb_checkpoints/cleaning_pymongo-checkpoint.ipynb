# %%
from pymongo import MongoClient

client = MongoClient('mongodb://localhost:27017/')
db = client.companies

# %%
import pandas as pd
data = db.companies.find({
    "offices":{
        "$not":{
            "$size":0
        }
    }})

data0 = pd.DataFrame(data)
data0.head()
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8b
# 1  52cdef7c4bab8bd675297d8c
# 2  52cdef7c4bab8bd675297d8a
# 3  52cdef7c4bab8bd675297d8f
# 4  52cdef7c4bab8bd675297d8d
#
#                                          acquisition  \
# 0                                               None
# 1                                               None
# 2  {'price_amount': 30000000, 'price_currency_cod...
# 3                                               None
# 4  {'price_amount': 500000, 'price_currency_code'...
#
#                                         acquisitions          alias_list  \
# 0                                                 []  Zoho ManageEngine
# 1                                                 []
# 2                                                 []
# 3                                                 []                None
# 4  [{'price_amount': None, 'price_currency_code':...
#
#                            blog_feed_url                       blog_url  \
# 0
# 1             http://blogs.zoho.com/feed         http://blogs.zoho.com/
# 2       http://digitalquarters.net/feed/    http://digitalquarters.net/
# 3  http://feeds.feedburner.com/omnidrive  http://www.omnidrive.com/blog
# 4        http://blog.digg.com/?feed=rss2          http://blog.digg.com/
#
#      category_code                                       competitions  \
# 0       enterprise                                                 []
# 1         software  [{'competitor': {'name': 'Empressr', 'permalin...
# 2              web  [{'competitor': {'name': 'Wikia', 'permalink':...
# 3  network_hosting  [{'competitor': {'name': 'Dropbox', 'permalink...
# 4             news  [{'competitor': {'name': 'Reddit', 'permalink'...
#
#                      created_at                               crunchbase_url  \
# 0           2007-05-25 19:24:22  http://www.crunchbase.com/company/adventnet
# 1  Fri May 25 19:30:28 UTC 2007       http://www.crunchbase.com/company/zoho
# 2           2007-05-25 06:51:27   http://www.crunchbase.com/company/wetpaint
# 3  Sun May 27 03:25:32 UTC 2007  http://www.crunchbase.com/company/omnidrive
# 4  Fri May 25 20:03:23 UTC 2007       http://www.crunchbase.com/company/digg
#
#    ...    phone_number                                           products  \
# 0  ...    925-924-9500                                                 []
# 1  ...  1-888-204-3539  [{'name': 'Zoho Office Suite', 'permalink': 'z...
# 2  ...    206.859.6300  [{'name': 'Wikison Wetpaint', 'permalink': 'we...
# 3  ...    660-675-5052  [{'name': 'Omnidrive', 'permalink': 'omnidrive'}]
# 4  ...  (415) 436-9638            [{'name': 'Digg', 'permalink': 'digg'}]
#
#                                        providerships  \
# 0  [{'title': 'DHFH', 'is_past': True, 'provider'...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'title': 'Public Relations', 'is_past': True...
#
#                                        relationships  \
# 0  [{'is_past': True, 'title': 'CEO and Co-Founde...
# 1  [{'is_past': False, 'title': 'CEO and Founder'...
# 2  [{'is_past': False, 'title': 'Co-Founder and V...
# 3  [{'is_past': True, 'title': 'Co-founder', 'per...
# 4  [{'is_past': False, 'title': 'CEO', 'person': ...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 94], 'assets/imag...
# 1                                                 []
# 2  [{'available_sizes': [[[150, 86], 'assets/imag...
# 3                                                 []
# 4  [{'available_sizes': [[[117, 150], 'assets/ima...
#
#                                             tag_list total_money_raised  \
# 0                                                                    $0
# 1  zoho, officesuite, spreadsheet, writer, projec...                 $0
# 2  wiki, seattle, elowitz, media-industry, media-...             $39.8M
# 3                     storage, sharing, edit, online              $800k
# 4  community, social, news, bookmark, digg, techn...               $45M
#
#    twitter_username                    updated_at  \
# 0      manageengine  Wed Oct 31 18:26:09 UTC 2012
# 1              zoho  Wed Oct 30 00:07:05 UTC 2013
# 2   BachelrWetpaint  Sun Dec 08 07:15:44 UTC 2013
# 3          Nomadesk  Tue Jul 02 22:48:04 UTC 2013
# 4              digg  Tue Nov 05 21:35:47 UTC 2013
#
#                                         video_embeds
# 0                                                 []
# 1  [{'embed_code': '<object width="430" height="2...
# 2                                                 []
# 3                                                 []
# 4  [{'embed_code': '<embed src="http://blip.tv/pl...
#
# [5 rows x 42 columns]

# %%
def getFirst(data):
    data = data['offices']
    principal = None
    if data[0]['latitude'] and data[0]['longitude']:
        principal = {
            "type":"Point",
            "coordinates":[data[0]['longitude'], data[0]['latitude']]
        }

    return {
        "totalOffices": len(data),
        "lat": data[0]['latitude'],
        "lng": data[0]['longitude'],
        "oficina_principal": principal
    }


data_office = data0[["offices"]].apply(getFirst, result_type="expand", axis=1)
data_office.head()
# Out:
#          lat         lng                                  oficina_principal  \
# 0  37.692934 -121.904945  {'type': 'Point', 'coordinates': [-121.904945,...
# 1  37.692934 -121.904945  {'type': 'Point', 'coordinates': [-121.904945,...
# 2  47.603122 -122.333253  {'type': 'Point', 'coordinates': [-122.333253,...
# 3        NaN         NaN                                                NaN
# 4  37.764726 -122.394523  {'type': 'Point', 'coordinates': [-122.394523,...
#
#    totalOffices
# 0           1.0
# 1           1.0
# 2           2.0
# 3           1.0
# 4           1.0

# %%
df_clean = pd.concat([data0,data_office], axis=1)
df_clean.head()
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8b
# 1  52cdef7c4bab8bd675297d8c
# 2  52cdef7c4bab8bd675297d8a
# 3  52cdef7c4bab8bd675297d8f
# 4  52cdef7c4bab8bd675297d8d
#
#                                          acquisition  \
# 0                                               None
# 1                                               None
# 2  {'price_amount': 30000000, 'price_currency_cod...
# 3                                               None
# 4  {'price_amount': 500000, 'price_currency_code'...
#
#                                         acquisitions          alias_list  \
# 0                                                 []  Zoho ManageEngine
# 1                                                 []
# 2                                                 []
# 3                                                 []                None
# 4  [{'price_amount': None, 'price_currency_code':...
#
#                            blog_feed_url                       blog_url  \
# 0
# 1             http://blogs.zoho.com/feed         http://blogs.zoho.com/
# 2       http://digitalquarters.net/feed/    http://digitalquarters.net/
# 3  http://feeds.feedburner.com/omnidrive  http://www.omnidrive.com/blog
# 4        http://blog.digg.com/?feed=rss2          http://blog.digg.com/
#
#      category_code                                       competitions  \
# 0       enterprise                                                 []
# 1         software  [{'competitor': {'name': 'Empressr', 'permalin...
# 2              web  [{'competitor': {'name': 'Wikia', 'permalink':...
# 3  network_hosting  [{'competitor': {'name': 'Dropbox', 'permalink...
# 4             news  [{'competitor': {'name': 'Reddit', 'permalink'...
#
#                      created_at                               crunchbase_url  \
# 0           2007-05-25 19:24:22  http://www.crunchbase.com/company/adventnet
# 1  Fri May 25 19:30:28 UTC 2007       http://www.crunchbase.com/company/zoho
# 2           2007-05-25 06:51:27   http://www.crunchbase.com/company/wetpaint
# 3  Sun May 27 03:25:32 UTC 2007  http://www.crunchbase.com/company/omnidrive
# 4  Fri May 25 20:03:23 UTC 2007       http://www.crunchbase.com/company/digg
#
#    ...                                        screenshots  \
# 0  ...  [{'available_sizes': [[[150, 94], 'assets/imag...
# 1  ...                                                 []
# 2  ...  [{'available_sizes': [[[150, 86], 'assets/imag...
# 3  ...                                                 []
# 4  ...  [{'available_sizes': [[[117, 150], 'assets/ima...
#
#                                             tag_list total_money_raised  \
# 0                                                                    $0
# 1  zoho, officesuite, spreadsheet, writer, projec...                 $0
# 2  wiki, seattle, elowitz, media-industry, media-...             $39.8M
# 3                     storage, sharing, edit, online              $800k
# 4  community, social, news, bookmark, digg, techn...               $45M
#
#    twitter_username                    updated_at  \
# 0      manageengine  Wed Oct 31 18:26:09 UTC 2012
# 1              zoho  Wed Oct 30 00:07:05 UTC 2013
# 2   BachelrWetpaint  Sun Dec 08 07:15:44 UTC 2013
# 3          Nomadesk  Tue Jul 02 22:48:04 UTC 2013
# 4              digg  Tue Nov 05 21:35:47 UTC 2013
#
#                                         video_embeds        lat         lng  \
# 0                                                 []  37.692934 -121.904945
# 1  [{'embed_code': '<object width="430" height="2...  37.692934 -121.904945
# 2                                                 []  47.603122 -122.333253
# 3                                                 []        NaN         NaN
# 4  [{'embed_code': '<embed src="http://blip.tv/pl...  37.764726 -122.394523
#
#                                    oficina_principal  totalOffices
# 0  {'type': 'Point', 'coordinates': [-121.904945,...           1.0
# 1  {'type': 'Point', 'coordinates': [-121.904945,...           1.0
# 2  {'type': 'Point', 'coordinates': [-122.333253,...           2.0
# 3                                                NaN           1.0
# 4  {'type': 'Point', 'coordinates': [-122.394523,...           1.0
#
# [5 rows x 46 columns]

# %%
df_clean.dropna(subset=['lat'], inplace=True) 
df_clean.head()
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8b
# 1  52cdef7c4bab8bd675297d8c
# 2  52cdef7c4bab8bd675297d8a
# 4  52cdef7c4bab8bd675297d8d
# 5  52cdef7c4bab8bd675297d91
#
#                                          acquisition  \
# 0                                               None
# 1                                               None
# 2  {'price_amount': 30000000, 'price_currency_cod...
# 4  {'price_amount': 500000, 'price_currency_code'...
# 5  {'price_amount': None, 'price_currency_code': ...
#
#                                         acquisitions          alias_list  \
# 0                                                 []  Zoho ManageEngine
# 1                                                 []
# 2                                                 []
# 4  [{'price_amount': None, 'price_currency_code':...
# 5                                                 []
#
#                       blog_feed_url                     blog_url  \
# 0
# 1        http://blogs.zoho.com/feed       http://blogs.zoho.com/
# 2  http://digitalquarters.net/feed/  http://digitalquarters.net/
# 4   http://blog.digg.com/?feed=rss2        http://blog.digg.com/
# 5    http://blog.geni.com/index.rdf         http://blog.geni.com
#
#   category_code                                       competitions  \
# 0    enterprise                                                 []
# 1  tech_company  [{'competitor': {'name': 'Empressr', 'permalin...
# 2  tech_company  [{'competitor': {'name': 'Wikia', 'permalink':...
# 4          news  [{'competitor': {'name': 'Reddit', 'permalink'...
# 5  tech_company  [{'competitor': {'name': 'Ancestry', 'permalin...
#
#                      created_at                               crunchbase_url  \
# 0           2007-05-25 19:24:22  http://www.crunchbase.com/company/adventnet
# 1  Fri May 25 19:30:28 UTC 2007       http://www.crunchbase.com/company/zoho
# 2           2007-05-25 06:51:27   http://www.crunchbase.com/company/wetpaint
# 4  Fri May 25 20:03:23 UTC 2007       http://www.crunchbase.com/company/digg
# 5  Thu May 31 19:52:34 UTC 2007       http://www.crunchbase.com/company/geni
#
#    ...                                        screenshots  \
# 0  ...  [{'available_sizes': [[[150, 94], 'assets/imag...
# 1  ...                                                 []
# 2  ...  [{'available_sizes': [[[150, 86], 'assets/imag...
# 4  ...  [{'available_sizes': [[[117, 150], 'assets/ima...
# 5  ...                                                 []
#
#                                             tag_list total_money_raised  \
# 0                                                                    $0
# 1  zoho, officesuite, spreadsheet, writer, projec...                 $0
# 2  wiki, seattle, elowitz, media-industry, media-...             $39.8M
# 4  community, social, news, bookmark, digg, techn...               $45M
# 5         geni, geneology, social, family, genealogy             $16.5M
#
#    twitter_username                    updated_at  \
# 0      manageengine  Wed Oct 31 18:26:09 UTC 2012
# 1              zoho  Wed Oct 30 00:07:05 UTC 2013
# 2   BachelrWetpaint  Sun Dec 08 07:15:44 UTC 2013
# 4              digg  Tue Nov 05 21:35:47 UTC 2013
# 5              geni  Wed Oct 10 14:01:29 UTC 2012
#
#                                         video_embeds        lat         lng  \
# 0                                                 []  37.692934 -121.904945
# 1  [{'embed_code': '<object width="430" height="2...  37.692934 -121.904945
# 2                                                 []  47.603122 -122.333253
# 4  [{'embed_code': '<embed src="http://blip.tv/pl...  37.764726 -122.394523
# 5  [{'embed_code': '<object width="425" height="3...  34.090368 -118.393064
#
#                                    oficina_principal  totalOffices
# 0  {'type': 'Point', 'coordinates': [-121.904945,...           1.0
# 1  {'type': 'Point', 'coordinates': [-121.904945,...           1.0
# 2  {'type': 'Point', 'coordinates': [-122.333253,...           2.0
# 4  {'type': 'Point', 'coordinates': [-122.394523,...           1.0
# 5  {'type': 'Point', 'coordinates': [-118.393064,...           1.0
#
# [5 rows x 46 columns]

# %%
print(df_clean.columns.values)
# Out:
# ['_id' 'acquisition' 'acquisitions' 'alias_list' 'blog_feed_url'
#  'blog_url' 'category_code' 'competitions' 'created_at' 'crunchbase_url'
#  'deadpooled_day' 'deadpooled_month' 'deadpooled_url' 'deadpooled_year'
#  'description' 'email_address' 'external_links' 'founded_day'
#  'founded_month' 'founded_year' 'funding_rounds' 'homepage_url' 'image'
#  'investments' 'ipo' 'milestones' 'name' 'number_of_employees' 'offices'
#  'overview' 'partners' 'permalink' 'phone_number' 'products'
#  'providerships' 'relationships' 'screenshots' 'tag_list'
#  'total_money_raised' 'twitter_username' 'updated_at' 'video_embeds' 'lat'
#  'lng' 'oficina_principal' 'totalOffices']

# %%
df_clean["category_code"].value_counts()
# Out:
# web                 2216
# software            1605
# games_video          603
# mobile               574
# advertising          568
# other                515
# enterprise           473
# ecommerce            378
# network_hosting      372
# consulting           370
# public_relations     315
# hardware             239
# biotech              219
# search               216
# cleantech            194
# security              98
# semiconductor         77
# analytics             53
# social                42
# finance               34
# news                  26
# education             25
# music                 25
# travel                21
# medical               20
# messaging             20
# photo_video           14
# manufacturing         13
# legal                 13
# health                13
# sports                 8
# real_estate            8
# automotive             7
# fashion                6
# nanotech               5
# hospitality            5
# transportation         4
# nonprofit              3
# design                 2
# local                  1
# Name: category_code, dtype: int64

# %%
import re
def business_catergoty(m):
    m = str(m)
    if (re.search('\s*(web)|(software)|(games_video)|(mobile)|(ecommerce)|(network_hosting)|(biotech)|(cleantech)|(analytics)|(nanotech)\s*', m)):
        return 'tech_company'
    else: return m



df_clean["category_code"]=df_clean["category_code"].apply(business_catergoty)

df_clean.head()
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8b
# 1  52cdef7c4bab8bd675297d8c
# 2  52cdef7c4bab8bd675297d8a
# 4  52cdef7c4bab8bd675297d8d
# 5  52cdef7c4bab8bd675297d91
#
#                                          acquisition  \
# 0                                               None
# 1                                               None
# 2  {'price_amount': 30000000, 'price_currency_cod...
# 4  {'price_amount': 500000, 'price_currency_code'...
# 5  {'price_amount': None, 'price_currency_code': ...
#
#                                         acquisitions          alias_list  \
# 0                                                 []  Zoho ManageEngine
# 1                                                 []
# 2                                                 []
# 4  [{'price_amount': None, 'price_currency_code':...
# 5                                                 []
#
#                       blog_feed_url                     blog_url  \
# 0
# 1        http://blogs.zoho.com/feed       http://blogs.zoho.com/
# 2  http://digitalquarters.net/feed/  http://digitalquarters.net/
# 4   http://blog.digg.com/?feed=rss2        http://blog.digg.com/
# 5    http://blog.geni.com/index.rdf         http://blog.geni.com
#
#   category_code                                       competitions  \
# 0    enterprise                                                 []
# 1  tech_company  [{'competitor': {'name': 'Empressr', 'permalin...
# 2  tech_company  [{'competitor': {'name': 'Wikia', 'permalink':...
# 4          news  [{'competitor': {'name': 'Reddit', 'permalink'...
# 5  tech_company  [{'competitor': {'name': 'Ancestry', 'permalin...
#
#                      created_at                               crunchbase_url  \
# 0           2007-05-25 19:24:22  http://www.crunchbase.com/company/adventnet
# 1  Fri May 25 19:30:28 UTC 2007       http://www.crunchbase.com/company/zoho
# 2           2007-05-25 06:51:27   http://www.crunchbase.com/company/wetpaint
# 4  Fri May 25 20:03:23 UTC 2007       http://www.crunchbase.com/company/digg
# 5  Thu May 31 19:52:34 UTC 2007       http://www.crunchbase.com/company/geni
#
#    ...                                        screenshots  \
# 0  ...  [{'available_sizes': [[[150, 94], 'assets/imag...
# 1  ...                                                 []
# 2  ...  [{'available_sizes': [[[150, 86], 'assets/imag...
# 4  ...  [{'available_sizes': [[[117, 150], 'assets/ima...
# 5  ...                                                 []
#
#                                             tag_list total_money_raised  \
# 0                                                                    $0
# 1  zoho, officesuite, spreadsheet, writer, projec...                 $0
# 2  wiki, seattle, elowitz, media-industry, media-...             $39.8M
# 4  community, social, news, bookmark, digg, techn...               $45M
# 5         geni, geneology, social, family, genealogy             $16.5M
#
#    twitter_username                    updated_at  \
# 0      manageengine  Wed Oct 31 18:26:09 UTC 2012
# 1              zoho  Wed Oct 30 00:07:05 UTC 2013
# 2   BachelrWetpaint  Sun Dec 08 07:15:44 UTC 2013
# 4              digg  Tue Nov 05 21:35:47 UTC 2013
# 5              geni  Wed Oct 10 14:01:29 UTC 2012
#
#                                         video_embeds        lat         lng  \
# 0                                                 []  37.692934 -121.904945
# 1  [{'embed_code': '<object width="430" height="2...  37.692934 -121.904945
# 2                                                 []  47.603122 -122.333253
# 4  [{'embed_code': '<embed src="http://blip.tv/pl...  37.764726 -122.394523
# 5  [{'embed_code': '<object width="425" height="3...  34.090368 -118.393064
#
#                                    oficina_principal  totalOffices
# 0  {'type': 'Point', 'coordinates': [-121.904945,...           1.0
# 1  {'type': 'Point', 'coordinates': [-121.904945,...           1.0
# 2  {'type': 'Point', 'coordinates': [-122.333253,...           2.0
# 4  {'type': 'Point', 'coordinates': [-122.394523,...           1.0
# 5  {'type': 'Point', 'coordinates': [-118.393064,...           1.0
#
# [5 rows x 46 columns]

# %%
df_clean1=df_clean[df_clean['deadpooled_year'].isna()]
df_clean1.head()
# Out:
#                         _id  \
# 4  52cdef7c4bab8bd675297d8d
# 5  52cdef7c4bab8bd675297d91
# 6  52cdef7c4bab8bd675297d92
# 7  52cdef7c4bab8bd675297d90
# 8  52cdef7c4bab8bd675297d93
#
#                                          acquisition  \
# 4  {'price_amount': 500000, 'price_currency_code'...
# 5  {'price_amount': None, 'price_currency_code': ...
# 6  {'price_amount': 20000000, 'price_currency_cod...
# 7  {'price_amount': 625000000, 'price_currency_co...
# 8                                               None
#
#                                         acquisitions alias_list  \
# 4  [{'price_amount': None, 'price_currency_code':...
# 5                                                 []
# 6                                                 []       None
# 7                                                 []       None
# 8  [{'price_amount': 20000000, 'price_currency_co...       None
#
#                                        blog_feed_url  \
# 4                    http://blog.digg.com/?feed=rss2
# 5                     http://blog.geni.com/index.rdf
# 6  http://www.flektor-blog.com/video_editing_soft...
# 7
# 8
#
#                       blog_url category_code  \
# 4        http://blog.digg.com/          news
# 5         http://blog.geni.com  tech_company
# 6  http://www.flektor-blog.com  tech_company
# 7                               tech_company
# 8                               tech_company
#
#                                         competitions  \
# 4  [{'competitor': {'name': 'Reddit', 'permalink'...
# 5  [{'competitor': {'name': 'Ancestry', 'permalin...
# 6  [{'competitor': {'name': 'RockYou', 'permalink...
# 7  [{'competitor': {'name': 'RescueTime', 'permal...
# 8                                                 []
#
#                      created_at  \
# 4  Fri May 25 20:03:23 UTC 2007
# 5  Thu May 31 19:52:34 UTC 2007
# 6  Thu May 31 21:11:51 UTC 2007
# 7  Fri Jun 08 12:19:51 UTC 2007
# 8  Thu May 31 21:46:57 UTC 2007
#
#                                       crunchbase_url  ...  \
# 4             http://www.crunchbase.com/company/digg  ...
# 5             http://www.crunchbase.com/company/geni  ...
# 6          http://www.crunchbase.com/company/flektor  ...
# 7          http://www.crunchbase.com/company/postini  ...
# 8  http://www.crunchbase.com/company/fox-interact...  ...
#
#                                          screenshots  \
# 4  [{'available_sizes': [[[117, 150], 'assets/ima...
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8  [{'available_sizes': [[[150, 94], 'assets/imag...
#
#                                             tag_list total_money_raised  \
# 4  community, social, news, bookmark, digg, techn...               $45M
# 5         geni, geneology, social, family, genealogy             $16.5M
# 6                              flektor, photo, video                 $0
# 7                                                                    $0
# 8                                                                    $0
#
#    twitter_username                    updated_at  \
# 4              digg  Tue Nov 05 21:35:47 UTC 2013
# 5              geni  Wed Oct 10 14:01:29 UTC 2012
# 6              None  Sat Nov 05 08:42:23 UTC 2011
# 7              None  Sat Aug 13 18:02:34 UTC 2011
# 8        twitterapi  Mon Aug 19 17:13:27 UTC 2013
#
#                                         video_embeds        lat         lng  \
# 4  [{'embed_code': '<embed src="http://blip.tv/pl...  37.764726 -122.394523
# 5  [{'embed_code': '<object width="425" height="3...  34.090368 -118.393064
# 6                                                 []  34.025958 -118.379768
# 7                                                 []  37.506885 -122.247573
# 8  [{'embed_code': '<embed src="http://blip.tv/pl...  34.076179 -118.394170
#
#                                    oficina_principal  totalOffices
# 4  {'type': 'Point', 'coordinates': [-122.394523,...           1.0
# 5  {'type': 'Point', 'coordinates': [-118.393064,...           1.0
# 6  {'type': 'Point', 'coordinates': [-118.379768,...           1.0
# 7  {'type': 'Point', 'coordinates': [-122.247573,...           1.0
# 8  {'type': 'Point', 'coordinates': [-118.39417, ...           1.0
#
# [5 rows x 46 columns]

# %%
df_clean1["total_money_raised"].value_counts()
# Out:
# $0         5982
# $10M         58
# $1M          52
# $5M          47
# $500k        37
# $3M          35
# $4M          30
# $2M          30
# $7M          27
# $8M          27
# $2.5M        26
# $100k        25
# $6M          24
# $15M         24
# $11M         23
# $600k        23
# $250k        21
# $12M         21
# $20M         19
# $16M         19
# $17M         18
# $1.5M        18
# $25M         18
# $30M         16
# $3.5M        16
# $7.5M        15
# $9M          15
# $27M         14
# $350k        13
# $150k        13
#            ...
# $224M         1
# $67.4M        1
# $35k          1
# $6.12M        1
# $64.2M        1
# $58.4M        1
# $3.44M        1
# $423k         1
# $1.08M        1
# $235M         1
# $430k         1
# $21.9M        1
# $16.2M        1
# $337M         1
# $50.4M        1
# $152M         1
# €2.6M         1
# $4.05M        1
# £32.8M        1
# $9.15M        1
# £2.25M        1
# $458M         1
# $355k         1
# C$11.3M       1
# $137M         1
# €589k         1
# $42.8M        1
# $77.2M        1
# $85.1M        1
# $27k          1
# Name: total_money_raised, Length: 1144, dtype: int64

# %%
def money_normalize(mo):
    if 'M' in mo:
        mo=mo.replace('M', '')
        return float(mo)*1000000
    elif 'k' in mo:
        mo=mo.replace('k', '')
        return float(mo)*1000
    elif 'B' in mo:
        mo=mo.replace('B', '')
        return float(mo) *1000000000
    else: return mo
    
def currency_normalize(mo):
    currencies= {
        'CAD': 1.3055728934, 'HKD': 7.8004458315, 'ISK': 126.348640214,'PHP': 51.3419527419, 'DKK': 6.6545697726,
        'HUF': 289.4872938029, 'CZK': 22.7454302274, 'GBP': 0.7991529202, 'RON': 4.2086491306, 'SEK': 9.4492197949,
        'IDR': 14110.0044583148, 'INR': 68.5648684797, 'BRL': 3.8120374498, 'RUB': 63.7561301828, 'HRK': 6.5942933571,
        'JPY': 108.6045474811, 'THB': 30.7748551048,'CHF': 0.992153366,'EUR': 0.8916629514,'MYR': 4.1405260811, 'BGN': 1.7439144004,
        'TRY': 5.7337494427, 'CNY': 6.8812304949, 'NOK': 8.6348640214, 'NZD': 1.5058403923, 'ZAR': 14.1607668301, 'USD': 1.0,
        'MXN': 18.9550601872,'SGD': 1.359518502,'AUD': 1.4318323674,'ILS': 3.5751226037,'KRW': 1178.8408381632,'PLN': 3.7922425323
    }
    if "C$" in mo:
        return money_normalize(mo.replace('C$',''))*currencies["CAD"]
    elif "$" in mo:
        return money_normalize(mo.replace('$',''))
    elif "kr" in mo:
        return money_normalize(mo.replace('kr',''))*currencies["KRW"]
    elif "r" in mo:
        return money_normalize(mo.replace('C',''))*currencies["RUB"]
    elif "€" in mo:
        return money_normalize(mo.replace('€',''))*currencies["EUR"]
    elif "£" in mo:
        return money_normalize(mo.replace('£',''))*currencies["GBP"]
    else:return mo
 


df_clean1["total_money_raised"]=df_clean1["total_money_raised"].apply(currency_normalize)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_clean1.columns
# Out:
# Index(['_id', 'acquisition', 'acquisitions', 'alias_list', 'blog_feed_url',
#        'blog_url', 'category_code', 'competitions', 'created_at',
#        'crunchbase_url', 'deadpooled_day', 'deadpooled_month',
#        'deadpooled_url', 'deadpooled_year', 'description', 'email_address',
#        'external_links', 'founded_day', 'founded_month', 'founded_year',
#        'funding_rounds', 'homepage_url', 'image', 'investments', 'ipo',
#        'milestones', 'name', 'number_of_employees', 'offices', 'overview',
#        'partners', 'permalink', 'phone_number', 'products', 'providerships',
#        'relationships', 'screenshots', 'tag_list', 'total_money_raised',
#        'twitter_username', 'updated_at', 'video_embeds', 'lat', 'lng',
#        'oficina_principal', 'totalOffices'],
#       dtype='object')

# %%
df_clean1.dropna(subset=['founded_year','number_of_employees'], inplace=True)
df_clean1.head()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                          _id  \
# 4   52cdef7c4bab8bd675297d8d
# 5   52cdef7c4bab8bd675297d91
# 8   52cdef7c4bab8bd675297d93
# 14  52cdef7c4bab8bd675297d97
# 15  52cdef7c4bab8bd675297d94
#
#                                           acquisition  \
# 4   {'price_amount': 500000, 'price_currency_code'...
# 5   {'price_amount': None, 'price_currency_code': ...
# 8                                                None
# 14                                               None
# 15                                               None
#
#                                          acquisitions alias_list  \
# 4   [{'price_amount': None, 'price_currency_code':...
# 5                                                  []
# 8   [{'price_amount': 20000000, 'price_currency_co...       None
# 14                                                 []
# 15  [{'price_amount': 15000000, 'price_currency_co...
#
#                               blog_feed_url                 blog_url  \
# 4           http://blog.digg.com/?feed=rss2    http://blog.digg.com/
# 5            http://blog.geni.com/index.rdf     http://blog.geni.com
# 8
# 14             http://blog.scribd.com/feed/  http://blog.scribd.com/
# 15  http://feeds.feedburner.com/TwitterBlog  http://twitter.com/blog
#
#    category_code                                       competitions  \
# 4           news  [{'competitor': {'name': 'Reddit', 'permalink'...
# 5   tech_company  [{'competitor': {'name': 'Ancestry', 'permalin...
# 8   tech_company                                                 []
# 14          news  [{'competitor': {'name': 'Docstoc', 'permalink...
# 15        social  [{'competitor': {'name': 'Digg', 'permalink': ...
#
#                       created_at  \
# 4   Fri May 25 20:03:23 UTC 2007
# 5   Thu May 31 19:52:34 UTC 2007
# 8   Thu May 31 21:46:57 UTC 2007
# 14  Sat Jun 02 07:34:05 UTC 2007
# 15  Fri Jun 01 08:42:34 UTC 2007
#
#                                        crunchbase_url  ...  \
# 4              http://www.crunchbase.com/company/digg  ...
# 5              http://www.crunchbase.com/company/geni  ...
# 8   http://www.crunchbase.com/company/fox-interact...  ...
# 14           http://www.crunchbase.com/company/scribd  ...
# 15          http://www.crunchbase.com/company/twitter  ...
#
#                                           screenshots  \
# 4   [{'available_sizes': [[[117, 150], 'assets/ima...
# 5                                                  []
# 8   [{'available_sizes': [[[150, 94], 'assets/imag...
# 14  [{'available_sizes': [[[150, 72], 'assets/imag...
# 15  [{'available_sizes': [[[150, 74], 'assets/imag...
#
#                                              tag_list total_money_raised  \
# 4   community, social, news, bookmark, digg, techn...            4.5e+07
# 5          geni, geneology, social, family, genealogy           1.65e+07
# 8                                                                      0
# 14  book-subscription, digital-library, netflix-fo...           2.58e+07
# 15  text, messaging, social, community, twitter, t...           1.16e+09
#
#     twitter_username                    updated_at  \
# 4               digg  Tue Nov 05 21:35:47 UTC 2013
# 5               geni  Wed Oct 10 14:01:29 UTC 2012
# 8         twitterapi  Mon Aug 19 17:13:27 UTC 2013
# 14            scribd  Sat Dec 14 00:46:12 UTC 2013
# 15           twitter  Sat Dec 07 16:07:56 UTC 2013
#
#                                          video_embeds        lat         lng  \
# 4   [{'embed_code': '<embed src="http://blip.tv/pl...  37.764726 -122.394523
# 5   [{'embed_code': '<object width="425" height="3...  34.090368 -118.393064
# 8   [{'embed_code': '<embed src="http://blip.tv/pl...  34.076179 -118.394170
# 14  [{'embed_code': '<script src="http://i.cdn.tur...  37.789634 -122.404052
# 15  [{'embed_code': '<iframe width="430" height="2...  37.776805 -122.416924
#
#                                     oficina_principal  totalOffices
# 4   {'type': 'Point', 'coordinates': [-122.394523,...           1.0
# 5   {'type': 'Point', 'coordinates': [-118.393064,...           1.0
# 8   {'type': 'Point', 'coordinates': [-118.39417, ...           1.0
# 14  {'type': 'Point', 'coordinates': [-122.404052,...           1.0
# 15  {'type': 'Point', 'coordinates': [-122.4169244...           1.0
#
# [5 rows x 46 columns]

# %%
df_clean1.isnull().sum(axis=0)
# Out:
# _id                       0
# acquisition            4456
# acquisitions              0
# alias_list             2772
# blog_feed_url            19
# blog_url                  1
# category_code             0
# competitions              0
# created_at                0
# crunchbase_url            0
# deadpooled_day         5009
# deadpooled_month       5009
# deadpooled_url         4926
# deadpooled_year        5009
# description            1325
# email_address             7
# external_links            0
# founded_day            2335
# founded_month          1307
# founded_year              0
# funding_rounds            0
# homepage_url              0
# image                    96
# investments               0
# ipo                    4899
# milestones                0
# name                      0
# number_of_employees       0
# offices                   0
# overview                  8
# partners                  0
# permalink                 0
# phone_number             10
# products                  0
# providerships             0
# relationships             0
# screenshots               0
# tag_list                108
# total_money_raised        0
# twitter_username       1528
# updated_at                0
# video_embeds              0
# lat                       0
# lng                       0
# oficina_principal         0
# totalOffices              0
# dtype: int64

# %%
df_clean1[['founded_year','number_of_employees']] = df_clean1[['founded_year','number_of_employees']].astype(int, errors='ignore')
# Out:
# /Users/claraFDEZ/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
df_clean2= df_clean1.drop(df_clean1[df_clean1['number_of_employees'] == 0].index)

df_clean2.head()
# Out:
#                          _id  \
# 4   52cdef7c4bab8bd675297d8d
# 5   52cdef7c4bab8bd675297d91
# 14  52cdef7c4bab8bd675297d97
# 15  52cdef7c4bab8bd675297d94
# 17  52cdef7c4bab8bd675297d9c
#
#                                           acquisition  \
# 4   {'price_amount': 500000, 'price_currency_code'...
# 5   {'price_amount': None, 'price_currency_code': ...
# 14                                               None
# 15                                               None
# 17                                               None
#
#                                          acquisitions alias_list  \
# 4   [{'price_amount': None, 'price_currency_code':...
# 5                                                  []
# 14                                                 []
# 15  [{'price_amount': 15000000, 'price_currency_co...
# 17                                                 []       None
#
#                               blog_feed_url                 blog_url  \
# 4           http://blog.digg.com/?feed=rss2    http://blog.digg.com/
# 5            http://blog.geni.com/index.rdf     http://blog.geni.com
# 14             http://blog.scribd.com/feed/  http://blog.scribd.com/
# 15  http://feeds.feedburner.com/TwitterBlog  http://twitter.com/blog
# 17
#
#    category_code                                       competitions  \
# 4           news  [{'competitor': {'name': 'Reddit', 'permalink'...
# 5   tech_company  [{'competitor': {'name': 'Ancestry', 'permalin...
# 14          news  [{'competitor': {'name': 'Docstoc', 'permalink...
# 15        social  [{'competitor': {'name': 'Digg', 'permalink': ...
# 17        social  [{'competitor': {'name': 'groovr', 'permalink'...
#
#                       created_at                             crunchbase_url  \
# 4   Fri May 25 20:03:23 UTC 2007     http://www.crunchbase.com/company/digg
# 5   Thu May 31 19:52:34 UTC 2007     http://www.crunchbase.com/company/geni
# 14  Sat Jun 02 07:34:05 UTC 2007   http://www.crunchbase.com/company/scribd
# 15  Fri Jun 01 08:42:34 UTC 2007  http://www.crunchbase.com/company/twitter
# 17  Thu Jun 07 11:41:44 UTC 2007  http://www.crunchbase.com/company/meetmoi
#
#     ...                                        screenshots  \
# 4   ...  [{'available_sizes': [[[117, 150], 'assets/ima...
# 5   ...                                                 []
# 14  ...  [{'available_sizes': [[[150, 72], 'assets/imag...
# 15  ...  [{'available_sizes': [[[150, 74], 'assets/imag...
# 17  ...                                                 []
#
#                                              tag_list total_money_raised  \
# 4   community, social, news, bookmark, digg, techn...            4.5e+07
# 5          geni, geneology, social, family, genealogy           1.65e+07
# 14  book-subscription, digital-library, netflix-fo...           2.58e+07
# 15  text, messaging, social, community, twitter, t...           1.16e+09
# 17          mobile, dating, location, realtime, phone           5.58e+06
#
#     twitter_username                    updated_at  \
# 4               digg  Tue Nov 05 21:35:47 UTC 2013
# 5               geni  Wed Oct 10 14:01:29 UTC 2012
# 14            scribd  Sat Dec 14 00:46:12 UTC 2013
# 15           twitter  Sat Dec 07 16:07:56 UTC 2013
# 17           meetmoi  Wed Aug 21 19:04:32 UTC 2013
#
#                                          video_embeds        lat         lng  \
# 4   [{'embed_code': '<embed src="http://blip.tv/pl...  37.764726 -122.394523
# 5   [{'embed_code': '<object width="425" height="3...  34.090368 -118.393064
# 14  [{'embed_code': '<script src="http://i.cdn.tur...  37.789634 -122.404052
# 15  [{'embed_code': '<iframe width="430" height="2...  37.776805 -122.416924
# 17  [{'embed_code': '<iframe src="http://player.vi...  40.757929  -73.985506
#
#                                     oficina_principal  totalOffices
# 4   {'type': 'Point', 'coordinates': [-122.394523,...           1.0
# 5   {'type': 'Point', 'coordinates': [-118.393064,...           1.0
# 14  {'type': 'Point', 'coordinates': [-122.404052,...           1.0
# 15  {'type': 'Point', 'coordinates': [-122.4169244...           1.0
# 17  {'type': 'Point', 'coordinates': [-73.985506, ...           1.0
#
# [5 rows x 46 columns]

# %%
df_clean3= df_clean2[df_clean2.total_money_raised != '0']
df_clean3.head()
# Out:
#                          _id  \
# 4   52cdef7c4bab8bd675297d8d
# 5   52cdef7c4bab8bd675297d91
# 14  52cdef7c4bab8bd675297d97
# 15  52cdef7c4bab8bd675297d94
# 17  52cdef7c4bab8bd675297d9c
#
#                                           acquisition  \
# 4   {'price_amount': 500000, 'price_currency_code'...
# 5   {'price_amount': None, 'price_currency_code': ...
# 14                                               None
# 15                                               None
# 17                                               None
#
#                                          acquisitions alias_list  \
# 4   [{'price_amount': None, 'price_currency_code':...
# 5                                                  []
# 14                                                 []
# 15  [{'price_amount': 15000000, 'price_currency_co...
# 17                                                 []       None
#
#                               blog_feed_url                 blog_url  \
# 4           http://blog.digg.com/?feed=rss2    http://blog.digg.com/
# 5            http://blog.geni.com/index.rdf     http://blog.geni.com
# 14             http://blog.scribd.com/feed/  http://blog.scribd.com/
# 15  http://feeds.feedburner.com/TwitterBlog  http://twitter.com/blog
# 17
#
#    category_code                                       competitions  \
# 4           news  [{'competitor': {'name': 'Reddit', 'permalink'...
# 5   tech_company  [{'competitor': {'name': 'Ancestry', 'permalin...
# 14          news  [{'competitor': {'name': 'Docstoc', 'permalink...
# 15        social  [{'competitor': {'name': 'Digg', 'permalink': ...
# 17        social  [{'competitor': {'name': 'groovr', 'permalink'...
#
#                       created_at                             crunchbase_url  \
# 4   Fri May 25 20:03:23 UTC 2007     http://www.crunchbase.com/company/digg
# 5   Thu May 31 19:52:34 UTC 2007     http://www.crunchbase.com/company/geni
# 14  Sat Jun 02 07:34:05 UTC 2007   http://www.crunchbase.com/company/scribd
# 15  Fri Jun 01 08:42:34 UTC 2007  http://www.crunchbase.com/company/twitter
# 17  Thu Jun 07 11:41:44 UTC 2007  http://www.crunchbase.com/company/meetmoi
#
#     ...                                        screenshots  \
# 4   ...  [{'available_sizes': [[[117, 150], 'assets/ima...
# 5   ...                                                 []
# 14  ...  [{'available_sizes': [[[150, 72], 'assets/imag...
# 15  ...  [{'available_sizes': [[[150, 74], 'assets/imag...
# 17  ...                                                 []
#
#                                              tag_list total_money_raised  \
# 4   community, social, news, bookmark, digg, techn...            4.5e+07
# 5          geni, geneology, social, family, genealogy           1.65e+07
# 14  book-subscription, digital-library, netflix-fo...           2.58e+07
# 15  text, messaging, social, community, twitter, t...           1.16e+09
# 17          mobile, dating, location, realtime, phone           5.58e+06
#
#     twitter_username                    updated_at  \
# 4               digg  Tue Nov 05 21:35:47 UTC 2013
# 5               geni  Wed Oct 10 14:01:29 UTC 2012
# 14            scribd  Sat Dec 14 00:46:12 UTC 2013
# 15           twitter  Sat Dec 07 16:07:56 UTC 2013
# 17           meetmoi  Wed Aug 21 19:04:32 UTC 2013
#
#                                          video_embeds        lat         lng  \
# 4   [{'embed_code': '<embed src="http://blip.tv/pl...  37.764726 -122.394523
# 5   [{'embed_code': '<object width="425" height="3...  34.090368 -118.393064
# 14  [{'embed_code': '<script src="http://i.cdn.tur...  37.789634 -122.404052
# 15  [{'embed_code': '<iframe width="430" height="2...  37.776805 -122.416924
# 17  [{'embed_code': '<iframe src="http://player.vi...  40.757929  -73.985506
#
#                                     oficina_principal  totalOffices
# 4   {'type': 'Point', 'coordinates': [-122.394523,...           1.0
# 5   {'type': 'Point', 'coordinates': [-118.393064,...           1.0
# 14  {'type': 'Point', 'coordinates': [-122.404052,...           1.0
# 15  {'type': 'Point', 'coordinates': [-122.4169244...           1.0
# 17  {'type': 'Point', 'coordinates': [-73.985506, ...           1.0
#
# [5 rows x 46 columns]

# %%
selected_columns=df_clean3[['name','category_code','tag_list','founded_year', 'number_of_employees', 'total_money_raised', 'offices', 'oficina_principal', 'lat', 'lng']]
selected_columns.head()
# Out:
#        name category_code                                           tag_list  \
# 4      Digg          news  community, social, news, bookmark, digg, techn...
# 5      Geni  tech_company         geni, geneology, social, family, genealogy
# 14   Scribd          news  book-subscription, digital-library, netflix-fo...
# 15  Twitter        social  text, messaging, social, community, twitter, t...
# 17  MeetMoi        social          mobile, dating, location, realtime, phone
#
#     founded_year  number_of_employees total_money_raised  \
# 4           2004                   60            4.5e+07
# 5           2006                   18           1.65e+07
# 14          2007                   50           2.58e+07
# 15          2006                 1300           1.16e+09
# 17          2007                   15           5.58e+06
#
#                                               offices  \
# 4   [{'description': None, 'address1': '135 Missis...
# 5   [{'description': 'Headquarters', 'address1': '...
# 14  [{'description': 'HQ', 'address1': '539 Bryant...
# 15  [{'description': '', 'address1': '1355 Market ...
# 17  [{'description': None, 'address1': '', 'addres...
#
#                                     oficina_principal        lat         lng
# 4   {'type': 'Point', 'coordinates': [-122.394523,...  37.764726 -122.394523
# 5   {'type': 'Point', 'coordinates': [-118.393064,...  34.090368 -118.393064
# 14  {'type': 'Point', 'coordinates': [-122.404052,...  37.789634 -122.404052
# 15  {'type': 'Point', 'coordinates': [-122.4169244...  37.776805 -122.416924
# 17  {'type': 'Point', 'coordinates': [-73.985506, ...  40.757929  -73.985506

# %%
import json as json
selected_columns.to_json('./companies_clean.json', orient='records')
